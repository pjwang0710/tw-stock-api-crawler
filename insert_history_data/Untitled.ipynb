# %%
from dotenv import load_dotenv
import json
import os
import pandas as pd
import requests
from sqlalchemy import create_engine
import datetime
import random
load_dotenv('.env')
# Out:
# True

# %%
proxies = ['45.15.223.0:9018', '45.146.180.69:9139', '107.152.222.227:9250', '45.128.247.174:7675', '107.152.197.223:8245', '45.94.47.121:8165', '181.177.91.167:8740', '144.168.241.216:8810', '85.209.130.100:7641', '45.137.43.47:7601', '45.142.28.114:8125', '45.137.84.15:7065', '91.246.193.60:6317', '45.154.56.114:7132', '91.246.194.18:6531', '193.23.253.69:7641', '193.27.10.145:6230', '5.154.253.30:8288', '185.95.157.83:6104', '45.128.245.61:9072', '193.5.251.127:7634', '45.154.58.50:7563', '109.207.130.19:8026', '45.9.122.183:8264', '2.56.101.189:8721', '45.154.58.133:7646', '185.245.27.157:6930', '5.157.130.247:8251', '185.245.27.137:6910', '37.35.40.139:8229', '176.116.231.146:7488', '91.246.192.118:6119', '193.27.23.101:9189', '200.0.61.246:6321', '176.116.230.111:7197', '185.245.26.2:6519', '200.0.61.74:6149', '37.35.41.124:8470', '185.205.194.228:7748', '193.8.231.198:9204', '45.154.244.47:8085', '84.21.188.31:8565', '64.43.91.183:6954', '64.43.90.82:6597', '185.95.157.166:6187', '45.137.43.35:7589', '185.205.194.175:7695', '45.154.84.72:8123', '85.209.129.127:8667', '200.0.61.213:6288', '45.155.70.242:8252', '45.137.40.176:8729', '37.35.40.188:8278', '176.116.230.61:7147', '45.87.249.192:7770', '37.35.40.185:8275', '5.154.253.219:8477', '5.157.130.77:8081', '45.131.212.146:6195', '5.154.253.155:8413', '176.116.231.110:7452', '193.23.253.82:7654', '45.92.247.84:6592', '45.130.60.81:9608', '85.209.129.114:8654', '45.131.212.68:6117', '45.72.55.105:7142', '2.56.101.175:8707', '85.209.130.145:7686', '45.86.15.18:8565', '5.154.253.114:8372', '193.23.253.88:7660', '193.23.253.115:7687', '45.72.55.201:7238', '45.72.55.127:7164', '45.72.55.200:7237', '45.72.55.174:7211', '45.130.60.129:9656', '45.130.60.228:9755', '45.130.60.123:9650', '2.56.101.136:8668', '45.92.247.166:6674', '45.131.212.244:6293', '185.95.157.190:6211', '45.87.249.197:7775', '185.95.157.131:6152', '45.131.212.246:6295', '45.87.249.15:7593', '45.92.247.197:6705', '2.56.101.219:8751', '45.130.60.107:9634', '185.95.157.117:6138', '45.131.212.138:6187', '45.92.247.141:6649', '45.92.247.241:6749', '45.87.249.249:7827', '193.151.160.57:8144', '193.151.160.143:8230', '193.151.161.119:8462', '193.151.161.60:8403']

# %%
SQLALCHEMY_DATALAKE_URI = os.getenv('SQLALCHEMY_DATALAKE_URI')
mysql_engine = create_engine(SQLALCHEMY_DATALAKE_URI, pool_pre_ping=True)

# %%
with open('stocks_id.json', 'r') as f:
    stocks_id = json.loads(f.read())

# %%
for i in range(len(stocks_id)):
    print(stocks_id[i])
# Out:
# 710575
# 3142
# 1909
# 6213
# 3694
# 2450
# 6021
# 5864
# 8936
# 5220
# 00674R
# 1813
# 00792B
# 00730
# 6548
# 8072
# 00724B
# 00656R
# 2411
# 5468
# 00701
# 6194
# 6472
# 2316
# 2342
# 2836A
# 1410
# 3234
# 4554
# 6486
# 2743
# 00665L
# 1337
# 1809
# 8409
# 6497
# 2442
# 6556
# 6109
# 6588
# 3556
# 3034
# 1808
# 8941
# 2495
# 00830
# 6161
# 6768
# 2230
# 2528
# 4722
# 2383
# 1232
# 2069
# 3048
# 3059
# 5514
# 2049
# 8271
# 5515
# 5410
# 3055
# 8929
# 6751
# 6111
# 2430
# 6004
# 2332
# 1626
# 1541
# 3516
# 3013
# 4155
# 5278
# 2329
# 00706L
# 3131
# 4192
# 1201
# 6261
# 6196
# 0057
# 6494
# 00774B
# 00636
# 8415
# 2327
# 4804
# 911610
# 6248
# 6264
# 9941A
# 3508
# 00872B
# 00885
# 3682
# 6206
# 3313
# 9912
# 1303
# 6117
# 6593
# 3701
# 00661
# 4716
# 0080
# 6269
# 00866
# 4106
# 3645
# 3680
# 5013
# 2351
# 9930
# 4729
# 5386
# 3325
# 3529
# 911868
# 2491
# 1516
# 708785
# 00668
# 1598
# 2543
# 5345
# 6218
# 00725B
# 00668K
# 1268
# 710566
# 8401
# 9917
# 6233
# 6752
# 1601
# 2328
# ...

# %%
import requests
import pandas as pd
sql = """
    INSERT INTO TaiwanStockFinancialStatements (date, stock_id, type, value, origin_name)
    VALUES (%(date)s, %(stock_id)s, %(type)s, %(value)s, %(origin_name)s)
    ON DUPLICATE KEY UPDATE value = value, origin_name = origin_name;
    """

for i, stock_id in enumerate(stocks_id):
    if i < 1580:
        continue
    print(i, stock_id)
    url = "https://api.finmindtrade.com/api/v4/data"
    parameter = {
        "dataset": "TaiwanStockFinancialStatements",
        "data_id": stock_id,
        "start_date": "2001-01-01",
    }
    proxy = random.choice(proxies)
    print(f'http://tihyjcyk-dest:sr9mbjac4xab@{proxy}')
    data = requests.get(url, params=parameter, proxies = {
        'http': f'http://tihyjcyk-dest:sr9mbjac4xab@{proxy}',
        'https': f'https://tihyjcyk-dest:sr9mbjac4xab@{proxy}'
    })
    data = data.json()['data']
    if data != []:
        with mysql_engine.connect() as connection:
            result = connection.execute(sql, data)
    else:
        print('====', stock_id)
# Out:
# 1580 6126
# http://tihyjcyk-dest:sr9mbjac4xab@45.154.58.50:7563
# 1581 4942
# http://tihyjcyk-dest:sr9mbjac4xab@45.94.47.121:8165
# 1582 2483
# http://tihyjcyk-dest:sr9mbjac4xab@109.207.130.19:8026
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2fb9f6e35220> in <module>
#      21     data = requests.get(url, params=parameter, proxies = {
#      22         'http': f'http://tihyjcyk-dest:sr9mbjac4xab@{proxy}',
# ---> 23         'https': f'https://tihyjcyk-dest:sr9mbjac4xab@{proxy}'
#      24     })
#      25     data = data.json()['data']
#
# ~/miniconda/envs/stock-api/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ...

# %%
data[43]
# Out:
# {'date': '2001-12-31',
#  'stock_id': '1909',
#  'type': 'CostOfGoodsSold',
#  'value': 985786000.0,
#  'origin_name': '營業成本'}

# %%
stocks_id[0]
# Out:
# '710575'

# %%
data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockFinancialStatements",
    "data_id": "2330",
    "start_date": "2001-01-01",
}
data = requests.get(url, params=parameter)
data = data.json()['data']

# %%
data
# Out:
# []

# %%
import requests
import pandas as pd
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockInfo",
    "token": "", # 參考登入，獲取金鑰
}
resp = requests.get(url, params=parameter)
data = resp.json()['data']

# %%
sql = """
    INSERT INTO TaiwanStockInfo (industry_category, stock_id, stock_name, type)
    VALUES (%(industry_category)s, %(stock_id)s, %(stock_name)s, %(type)s) ;
    """

with mysql_engine.connect() as connection:
    result = connection.execute(sql, data)

# %%
stocks_id = []
for d in data:
    stocks_id.append(d['stock_id'])

# %%
stocks_id = list(set(stocks_id))

# %%
with open('stocks_id.json', 'a+') as f:
    f.write(json.dumps(stocks_id))

# %%
url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockBalanceSheet",
    "data_id": '2330',
    "start_date": "2001-01-01",
}
proxy = random.choice(proxies)
print(f'http://tihyjcyk-dest:sr9mbjac4xab@{proxy}')
data = requests.get(url, params=parameter, proxies = {
    'http': f'http://tihyjcyk-dest:sr9mbjac4xab@{proxy}',
    'https': f'https://tihyjcyk-dest:sr9mbjac4xab@{proxy}'
})
data = data.json()['data']
# Out:
# http://tihyjcyk-dest:sr9mbjac4xab@45.137.43.35:7589

# %%
data
# Out:
# [{'date': '2012-03-31',
#   'stock_id': '2330',
#   'type': 'AccountsPayable',
#   'value': 13262100000.0,
#   'origin_name': '應付帳款'},
#  {'date': '2012-03-31',
#   'stock_id': '2330',
#   'type': 'AccountsPayable_per',
#   'value': 1.58,
#   'origin_name': '應付帳款'},
#  {'date': '2012-03-31',
#   'stock_id': '2330',
#   'type': 'AccountsPayableToRelatedParties',
#   'value': 906317000.0,
#   'origin_name': '應付帳款－關係人'},
#  {'date': '2012-03-31',
#   'stock_id': '2330',
#   'type': 'AccountsPayableToRelatedParties_per',
#   'value': 0.11,
#   'origin_name': '應付帳款－關係人'},
#  {'date': '2012-03-31',
#   'stock_id': '2330',
#   'type': 'AccountsReceivableDuefromRelatedPartiesNet',
#   'value': 647314000.0,
#   'origin_name': '應收帳款－關係人淨額'},
#  {'date': '2012-03-31',
#   'stock_id': '2330',
#   'type': 'AccountsReceivableDuefromRelatedPartiesNet_per',
#   'value': 0.08,
#   'origin_name': '應收帳款－關係人淨額'},
#  {'date': '2012-03-31',
#   'stock_id': '2330',
#   'type': 'AccountsReceivableNet',
# ...

# %%
import requests
import json
import pandas as pd

url = "https://api.finmindtrade.com/api/v4/data"
parameter = {
    "dataset": "TaiwanStockPrice",
    "data_id": "2330",
    "start_date": "2001-01-01",
    "end_date": "2021-05-14",
    "token": ""
}
    
    
# url = "https://api.finmindtrade.com/api/v4/data"
# parameter = {
#     "dataset": "TaiwanStockPrice",
#     "data_id": "2330",
#     "start_date": "2001-01-01",
#     "end_date": "2021-05-14",
#     "token": "", # 參考登入，獲取金鑰
# }
resp = requests.get(url, params=parameter)
data = resp.json()
data = pd.DataFrame(data["data"])

# %%
resp.json()
# Out:
# {'msg': 'success',
#  'status': 200,
#  'data': [{'date': '2001-01-02',
#    'stock_id': '2330',
#    'Trading_Volume': 31479000,
#    'Trading_money': 2566521500,
#    'open': 78.0,
#    'max': 83.5,
#    'min': 77.5,
#    'close': 83.5,
#    'spread': 5.0,
#    'Trading_turnover': 11090},
#   {'date': '2001-01-03',
#    'stock_id': '2330',
#    'Trading_Volume': 31730662,
#    'Trading_money': 2570508796,
#    'open': 80.5,
#    'max': 82.5,
#    'min': 79.5,
#    'close': 80.5,
#    'spread': -3.0,
#    'Trading_turnover': 10951},
#   {'date': '2001-01-04',
#    'stock_id': '2330',
#    'Trading_Volume': 67142307,
#    'Trading_money': 5697822128,
#    'open': 85.5,
#    'max': 86.0,
#    'min': 83.5,
#    'close': 85.0,
#    'spread': 4.5,
#    'Trading_turnover': 18595},
#   {'date': '2001-01-05',
#    'stock_id': '2330',
#    'Trading_Volume': 57537998,
#    'Trading_money': 5044495349,
#    'open': 85.0,
#    'max': 90.5,
#    'min': 85.0,
#    'close': 90.5,
# ...

# %%
import json
with open('stocks_id.json', 'r') as f:
    stocks_ids = json.loads(f.read())

# %%
search_stocks = ['tse_1101.tw','tse_1102.tw','tse_1103.tw','tse_1104.tw','tse_1107.tw','tse_1109.tw','tse_1110.tw','tse_1201.tw','tse_1203.tw','tse_1204.tw','tse_1207.tw','tse_1210.tw','tse_1212.tw','tse_1213.tw','tse_1215.tw','tse_1216.tw','tse_1217.tw','tse_1218.tw','tse_1219.tw','tse_1220.tw','tse_1221.tw','tse_1224.tw','tse_1225.tw','tse_1227.tw','tse_1228.tw','tse_1229.tw','tse_1231.tw','tse_1232.tw','tse_1233.tw','tse_1234.tw','tse_1235.tw','tse_1236.tw','tse_1301.tw','tse_1303.tw','tse_1304.tw','tse_1305.tw','tse_1306.tw','tse_1307.tw','tse_1308.tw','tse_1309.tw','tse_1310.tw','tse_1311.tw','tse_1312.tw','tse_1313.tw','tse_1314.tw','tse_1315.tw','tse_1316.tw','tse_1319.tw','tse_1321.tw','tse_1323.tw','tse_1324.tw','tse_1325.tw','tse_1326.tw','tse_1402.tw','tse_1407.tw','tse_1408.tw','tse_1409.tw','tse_1410.tw','tse_1413.tw','tse_1414.tw','tse_1416.tw','tse_1417.tw','tse_1418.tw','tse_1419.tw','tse_1423.tw','tse_1432.tw','tse_1434.tw','tse_1435.tw','tse_1436.tw','tse_1437.tw','tse_1438.tw','tse_1439.tw','tse_1440.tw','tse_1441.tw','tse_1442.tw','tse_1443.tw','tse_1444.tw','tse_1445.tw','tse_1446.tw','tse_1447.tw','tse_1449.tw','tse_1450.tw','tse_1451.tw','tse_1452.tw','tse_1453.tw','tse_1454.tw','tse_1455.tw','tse_1456.tw','tse_1457.tw','tse_1458.tw','tse_1459.tw','tse_1460.tw','tse_1462.tw','tse_1463.tw','tse_1464.tw','tse_1465.tw','tse_1466.tw','tse_1467.tw','tse_1468.tw','tse_1469.tw','tse_1470.tw','tse_1471.tw','tse_1472.tw','tse_1473.tw','tse_1474.tw','tse_1475.tw','tse_1476.tw','tse_1477.tw','tse_1503.tw','tse_1504.tw','tse_1506.tw','tse_1507.tw','tse_1510.tw','tse_1512.tw','tse_1513.tw','tse_1514.tw','tse_1515.tw','tse_1516.tw','tse_1517.tw','tse_1519.tw','tse_1520.tw','tse_1521.tw','tse_1522.tw','tse_1523.tw','tse_1524.tw','tse_1525.tw','tse_1526.tw','tse_1527.tw','tse_1528.tw','tse_1529.tw','tse_1530.tw','tse_1531.tw','tse_1532.tw','tse_1533.tw','tse_1534.tw','tse_1535.tw','tse_1536.tw','tse_1537.tw','tse_1538.tw','tse_1539.tw','tse_1540.tw','tse_1541.tw','tse_1601.tw','tse_1602.tw','tse_1603.tw','tse_1604.tw','tse_1605.tw','tse_1606.tw','tse_1608.tw','tse_1609.tw','tse_1611.tw','tse_1612.tw','tse_1613.tw','tse_1614.tw','tse_1615.tw','tse_1616.tw','tse_1617.tw','tse_1618.tw','tse_1701.tw','tse_1702.tw','tse_1704.tw','tse_1707.tw','tse_1708.tw','tse_1709.tw','tse_1710.tw','tse_1711.tw','tse_1712.tw','tse_1713.tw','tse_1714.tw','tse_1715.tw','tse_1716.tw','tse_1717.tw','tse_1718.tw','tse_1720.tw','tse_1721.tw','tse_1722.tw','tse_1723.tw','tse_1724.tw','tse_1725.tw','tse_1726.tw','tse_1727.tw','tse_1729.tw','tse_1730.tw','tse_1731.tw','tse_1732.tw','tse_1733.tw','tse_1734.tw']

# %%
len(search_stocks)
# Out:
# 187

# %%
# Out:
# ['tse_710575.tw',
#  'tse_3142.tw',
#  'tse_1909.tw',
#  'tse_6213.tw',
#  'tse_3694.tw',
#  'tse_2450.tw',
#  'tse_6021.tw',
#  'tse_5864.tw',
#  'tse_8936.tw',
#  'tse_5220.tw',
#  'tse_00674R.tw',
#  'tse_1813.tw',
#  'tse_00792B.tw',
#  'tse_00730.tw',
#  'tse_6548.tw',
#  'tse_8072.tw',
#  'tse_00724B.tw',
#  'tse_00656R.tw',
#  'tse_2411.tw',
#  'tse_5468.tw',
#  'tse_00701.tw',
#  'tse_6194.tw',
#  'tse_6472.tw',
#  'tse_2316.tw',
#  'tse_2342.tw',
#  'tse_2836A.tw',
#  'tse_1410.tw',
#  'tse_3234.tw',
#  'tse_4554.tw',
#  'tse_6486.tw',
#  'tse_2743.tw',
#  'tse_00665L.tw',
#  'tse_1337.tw',
#  'tse_1809.tw',
#  'tse_8409.tw',
#  'tse_6497.tw',
#  'tse_2442.tw',
#  'tse_6556.tw',
#  'tse_6109.tw',
#  'tse_6588.tw',
#  'tse_3556.tw',
#  'tse_3034.tw',
#  'tse_1808.tw',
#  'tse_8941.tw',
#  'tse_2495.tw',
#  'tse_00830.tw',
#  'tse_6161.tw',
#  'tse_6768.tw',
#  'tse_2230.tw',
#  'tse_2528.tw',
#  'tse_4722.tw',
#  'tse_2383.tw',
#  'tse_1232.tw',
#  'tse_2069.tw',
# ...

# %%
search_key_1 = '|'.join(search_stocks[:len(search_stocks)//2])
search_key_2 = '|'.join(search_stocks[len(search_stocks)//2:])
url = f'https://mis.twse.com.tw/stock/api/getStockInfo.jsp?ex_ch={search_key_1}&json=1&delay=0&_=1621142768447'
r = requests.get(url)
print(len(json.loads(r.content)['msgArray']))

url = f'https://mis.twse.com.tw/stock/api/getStockInfo.jsp?ex_ch={search_key_2}&json=1&delay=0&_=1621142768447'
r = requests.get(url)
print(len(json.loads(r.content)['msgArray']))
# Out:
# 79
# 81

# %%
json.loads(r.content)
# Out:
# {'msgArray': [{'tv': '-',
#    'c': '1463',
#    'd': '20210514',
#    'ch': '1463.tw',
#    'ip': '0',
#    'i': '04',
#    'it': '12',
#    'n': '強盛',
#    'p': '0',
#    'ex': 'tse',
#    's': '-',
#    't': '07:50:00',
#    'u': '14.1000',
#    'w': '11.6000',
#    'nf': '強盛染整股份有限公司',
#    'y': '12.8500',
#    'z': '-'},
#   {'tv': '-',
#    'c': '1464',
#    'd': '20210514',
#    'ch': '1464.tw',
#    'ip': '0',
#    'i': '04',
#    'it': '12',
#    'n': '得力',
#    'p': '0',
#    'ex': 'tse',
#    's': '-',
#    't': '07:50:00',
#    'u': '18.6000',
#    'w': '15.3000',
#    'nf': '得力實業股份有限公司',
#    'y': '16.9500',
#    'z': '-'},
#   {'tv': '-',
#    'c': '1465',
#    'd': '20210514',
#    'ch': '1465.tw',
#    'ip': '0',
#    'i': '04',
#    'it': '12',
#    'n': '偉全',
#    'p': '0',
#    'ex': 'tse',
#    's': '-',
#    't': '07:50:00',
#    'u': '13.8000',
#    'w': '11.3000',
#    'nf': '偉全實業股份有限公司',
#    'y': '12.5500',
#    'z': '-'},
#   {'tv': '-',
#    'c': '1466',
# ...

# %%
import datetime

# %%
datetime.datetime.fromtimestamp(1621143810702/1000)
# Out:
# datetime.datetime(2021, 5, 16, 5, 43, 30, 702000)

# %%
datetime.datetime.fromtimestamp(1621143810732/1000)
# Out:
# datetime.datetime(2021, 5, 16, 5, 43, 30, 732000)

# %%
search_keys = '|'.join([f'tse_{item}.tw'for item in stocks_ids[:len(stocks_ids)//5]])
url = f'https://mis.twse.com.tw/stock/api/getStockInfo.jsp?ex_ch=tse_1463.tw'
r = requests.get(url)
print(json.loads(r.content))
# print(len(json.loads(r.content)['msgArray']))
# Out:
# {'msgArray': [{'tv': '-', 'c': '1463', 'd': '20210514', 'ch': '1463.tw', 'ip': '0', 'i': '04', 'it': '12', 'n': '強盛', 'p': '0', 'ex': 'tse', 's': '-', 't': '07:50:00', 'u': '14.1000', 'w': '11.6000', 'nf': '強盛染整股份有限公司', 'y': '12.8500', 'z': '-'}], 'referer': '', 'userDelay': 5000, 'rtcode': '0000', 'queryTime': {'sysDate': '20210516', 'stockInfoItem': 168, 'stockInfo': 112007, 'sessionStr': 'UserSession', 'sysTime': '14:29:05', 'showChart': False, 'sessionFromTime': -1, 'sessionLatestTime': -1}, 'rtmessage': 'OK', 'exKey': 'if_tse_1463.tw_zh-tw.null', 'cachedAlive': 6842}

# %%
search_keys
# Out:
# 'tse_710575.tw|tse_3142.tw|tse_1909.tw|tse_6213.tw|tse_3694.tw|tse_2450.tw|tse_6021.tw|tse_5864.tw|tse_8936.tw|tse_5220.tw|tse_00674R.tw|tse_1813.tw|tse_00792B.tw|tse_00730.tw|tse_6548.tw|tse_8072.tw|tse_00724B.tw|tse_00656R.tw|tse_2411.tw|tse_5468.tw|tse_00701.tw|tse_6194.tw|tse_6472.tw|tse_2316.tw|tse_2342.tw|tse_2836A.tw|tse_1410.tw|tse_3234.tw|tse_4554.tw|tse_6486.tw|tse_2743.tw|tse_00665L.tw|tse_1337.tw|tse_1809.tw|tse_8409.tw|tse_6497.tw|tse_2442.tw|tse_6556.tw|tse_6109.tw|tse_6588.tw|tse_3556.tw|tse_3034.tw|tse_1808.tw|tse_8941.tw|tse_2495.tw|tse_00830.tw|tse_6161.tw|tse_6768.tw|tse_2230.tw|tse_2528.tw|tse_4722.tw|tse_2383.tw|tse_1232.tw|tse_2069.tw|tse_3048.tw|tse_3059.tw|tse_5514.tw|tse_2049.tw|tse_8271.tw|tse_5515.tw|tse_5410.tw|tse_3055.tw|tse_8929.tw|tse_6751.tw|tse_6111.tw|tse_2430.tw|tse_6004.tw|tse_2332.tw|tse_1626.tw|tse_1541.tw|tse_3516.tw|tse_3013.tw|tse_4155.tw|tse_5278.tw|tse_2329.tw|tse_00706L.tw|tse_3131.tw|tse_4192.tw|tse_1201.tw|tse_6261.tw|tse_6196.tw|tse_005
# ...

# %%
import requests
import pandas as pd

# %%
url = 'https://isin.twse.com.tw/isin/C_public.jsp?strMode=2'
r = requests.get(url)
df_list = pd.read_html(r.text, header=None) 

rename_pair = {
    0: 'raw_stock_id',
    1: 'isin_code',
    2: 'start_date',
    3: 'market_type',
    4: 'industry_type',
    5: 'cfi_code',
    6: 'note'
}
df = df_list[0]
df = df[df[3] == '上市']
df = df.fillna('')
df = df.rename(columns=rename_pair)
df['raw_stock_id'] = df['raw_stock_id'].apply(lambda x: x.replace(' ', '　'))
df['start_date'] = df['start_date'].apply(lambda x: datetime.datetime.strptime(x, '%Y/%m/%d'))
df['stock_id'] = df['raw_stock_id'].apply(lambda x: x.split('　')[0])
df['stock_name'] = df['raw_stock_id'].apply(lambda x: x.split('　')[1])

# %%
df[df['stock_id'] == '0050']
# Out:
#       raw_stock_id     isin_code start_date market_type industry_type  \
# 24355  0050　元大台灣50  TW0000050004 2003-06-30          上市
#
#       cfi_code note stock_id  stock_check stock_name
# 24355   CEOGEU          0050            2     元大台灣50

# %%
for stock_id in df['stock_id']:
    print(stock_id)
# Out:
# 1101
# 1102
# 1103
# 1104
# 1108
# 1109
# 1110
# 1201
# 1203
# 1210
# 1213
# 1215
# 1216
# 1217
# 1218
# 1219
# 1220
# 1225
# 1227
# 1229
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# 1256
# 1301
# 1303
# 1304
# 1305
# 1307
# 1308
# 1309
# 1310
# 1312
# 1313
# 1314
# 1315
# 1316
# 1319
# 1321
# 1323
# 1324
# 1325
# 1326
# 1337
# 1338
# 1339
# 1340
# 1341
# 1342
# 1402
# 1409
# 1410
# 1413
# 1414
# 1416
# 1417
# 1418
# 1419
# 1423
# 1432
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# 1446
# 1447
# 1449
# 1451
# 1452
# 1453
# 1454
# 1455
# 1456
# 1457
# 1459
# 1460
# 1463
# 1464
# 1465
# 1466
# 1467
# 1468
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1503
# 1504
# 1506
# 1507
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1519
# 1521
# 1522
# 1524
# 1525
# 1526
# 1527
# 1528
# 1529
# 1530
# 1531
# 1532
# 1533
# 1535
# 1536
# 1537
# 1538
# 1539
# 1540
# 1541
# 1558
# 1560
# 1568
# 1582
# 1583
# 1587
# 1589
# 1590
# 1592
# 1597
# 1598
# ...

# %%
df
# Out:
#                    0             1           2   3     4       5    6  \
# 2            1101　台泥  TW0001101004  1962/02/09  上市  水泥工業  ESVUFR  NaN
# 3            1102　亞泥  TW0001102002  1962/06/08  上市  水泥工業  ESVUFR  NaN
# 4            1103　嘉泥  TW0001103000  1969/11/14  上市  水泥工業  ESVUFR  NaN
# 5            1104　環泥  TW0001104008  1971/02/01  上市  水泥工業  ESVUFR  NaN
# 6            1108　幸福  TW0001108009  1990/06/06  上市  水泥工業  ESVUFR  NaN
# ...              ...           ...         ...  ..   ...     ...  ...
# 24514  01003T　兆豐新光R1  TW00001003T4  2005/12/26  上市   NaN  CBCIXU  NaN
# 24515  01004T　土銀富邦R2  TW00001004T2  2006/04/13  上市   NaN  CBCIXU  NaN
# 24516  01007T　兆豐國泰R2  TW00001007T5  2006/10/13  上市   NaN  CBCIXU  NaN
# 24517  01009T　王道圓滿R1  TW00001009T1  2018/06/21  上市   NaN  CBCIXU  NaN
# 24518  01010T　京城樂富R1  TW00001010T9  2018/12/05  上市   NaN  CBCIXU  NaN
#
#       stock_id  stock_check stock_name
# 2         1101            2         台泥
# 3         1102            2         亞泥
# ...

# %%
import json

# %%
all_stock_url = 'https://mis.twse.com.tw/stock/api/getStockNames.jsp?n=1&_=1621148712213'
r = requests.get(all_stock_url)

# %%
msg = json.loads(r.content)

# %%
msg['datas']
# Out:
# [{'c': '1101', 'key': 'tse_1101.tw_20210514', 'n': '台泥'},
#  {'c': '1102', 'key': 'tse_1102.tw_20210514', 'n': '亞泥'},
#  {'c': '1103', 'key': 'tse_1103.tw_20210514', 'n': '嘉泥'},
#  {'c': '1104', 'key': 'tse_1104.tw_20210514', 'n': '環泥'},
#  {'c': '1108', 'key': 'tse_1108.tw_20210514', 'n': '幸福'},
#  {'c': '1109', 'key': 'tse_1109.tw_20210514', 'n': '信大'},
#  {'c': '1110', 'key': 'tse_1110.tw_20210514', 'n': '東泥'},
#  {'c': '1201', 'key': 'tse_1201.tw_20210514', 'n': '味全'},
#  {'c': '1203', 'key': 'tse_1203.tw_20210514', 'n': '味王'},
#  {'c': '1210', 'key': 'tse_1210.tw_20210514', 'n': '大成'},
#  {'c': '1213', 'key': 'tse_1213.tw_20210514', 'n': '大飲'},
#  {'c': '1215', 'key': 'tse_1215.tw_20210514', 'n': '卜蜂'},
#  {'c': '1216', 'key': 'tse_1216.tw_20210514', 'n': '統一'},
#  {'c': '1217', 'key': 'tse_1217.tw_20210514', 'n': '愛之味'},
#  {'c': '1218', 'key': 'tse_1218.tw_20210514', 'n': '泰山'},
#  {'c': '1219', 'key': 'tse_1219.tw_20210514', 'n': '福壽'},
# ...

# %%
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine

load_dotenv('.env')

SQLALCHEMY_DATALAKE_URI = os.getenv('SQLALCHEMY_DATALAKE_URI')
mysql_engine = create_engine(SQLALCHEMY_DATALAKE_URI, pool_pre_ping=True)

def insert_to_db(data):
    sql = """
          INSERT INTO TaiwanStockFiveMinuteStockInfo (stock_id, url_key, name)
          VALUES (%(c)s, %(key)s, %(n)s)
          ON DUPLICATE KEY UPDATE url_key = url_key, name=name;
          """    
    with mysql_engine.connect() as connection:
        result = connection.execute(sql, data)

# %%
insert_to_db(msg['datas'])

# %%
sql = "SELECT stock_id from TaiwanStockFiveMinuteStockInfo"
with mysql_engine.connect() as connection:
    result = connection.execute(sql).fetchall()

# %%
stocks_id = [f'tse_{item[0]}.tw' for item in result]

# %%
stocks_id
# Out:
# ['tse_030008.tw',
#  'tse_030009.tw',
#  'tse_030034.tw',
#  'tse_030035.tw',
#  'tse_030036.tw',
#  'tse_030037.tw',
#  'tse_030038.tw',
#  'tse_030039.tw',
#  'tse_030066.tw',
#  'tse_030067.tw',
#  'tse_030068.tw',
#  'tse_030087.tw',
#  'tse_030088.tw',
#  'tse_030089.tw',
#  'tse_030119.tw',
#  'tse_030120.tw',
#  'tse_030121.tw',
#  'tse_030165.tw',
#  'tse_030177.tw',
#  'tse_030178.tw',
#  'tse_030190.tw',
#  'tse_030191.tw',
#  'tse_030192.tw',
#  'tse_030193.tw',
#  'tse_030194.tw',
#  'tse_030195.tw',
#  'tse_030235.tw',
#  'tse_030236.tw',
#  'tse_030237.tw',
#  'tse_030238.tw',
#  'tse_030239.tw',
#  'tse_030302.tw',
#  'tse_030329.tw',
#  'tse_030330.tw',
#  'tse_030383.tw',
#  'tse_030384.tw',
#  'tse_030385.tw',
#  'tse_030386.tw',
#  'tse_030387.tw',
#  'tse_030388.tw',
#  'tse_030389.tw',
#  'tse_030474.tw',
#  'tse_030475.tw',
#  'tse_030476.tw',
#  'tse_030477.tw',
#  'tse_030478.tw',
#  'tse_030494.tw',
#  'tse_030495.tw',
#  'tse_030507.tw',
#  'tse_030595.tw',
# ...

# %%
batch = 80
size = len(stocks_id)//batch
data = []
for s in range(size+1):
    print(s)
    search_keys = '|'.join(stocks_id[s*batch:(s+1)*batch])
    if search_keys != '':
        url = f'https://mis.twse.com.tw/stock/api/getStockInfo.jsp?ex_ch={search_keys}'
        r = requests.get(url)
        data += json.loads(r.content)['msgArray']
    break
# Out:
# 0

# %%
len(stocks_id)//30
# Out:
# 76

# %%
'|'.join([]) == ''
# Out:
# True

# %%
len(data)
# Out:
# 2148

# %%
data[0]
# Out:
# {'tv': '-',
#  'rch': '1717',
#  'a': '1.5000_1.5200_1.6000_',
#  'b': '0.7900_0.2600_0.0600_',
#  'c': '030008',
#  'd': '20210514',
#  'ch': '030008.tw',
#  'tlong': '1620970200000',
#  'io': 'W2',
#  'f': '10_5_5_',
#  'ip': '0',
#  'g': '25_61_20_',
#  'mt': '000000',
#  'it': '06',
#  'n': '長興元富0B購01',
#  'p': '0',
#  'ex': 'tse',
#  's': '-',
#  't': '13:30:00',
#  'u': '1.7600',
#  'v': '0',
#  'w': '0.0200',
#  'nf': '長興元富0B購01  －長興            20211108美購',
#  'y': '0.8900',
#  'z': '-',
#  'rn': '長興',
#  'ts': '0'}

# %%
# a 賣出價格 f 賣出張數
# b 買入價格 g 買入張數
# c 股票代號
# v 累積成交量 
# t 時間
# h 當日最高
# l 當日最低
# o 開盤
# z 成交價
# s 成交量

# %%
sql = """
      INSERT INTO TaiwanStockFiveMinuteStockInfo (stock_id, url_key, name)
      VALUES (%(c)s, %(key)s, %(n)s)
      ON DUPLICATE KEY UPDATE url_key = url_key, name=name;
      """
